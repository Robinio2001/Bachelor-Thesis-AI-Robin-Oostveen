# %%
import pandas as pd
import numpy as np

# %%
import sys
sys.path.insert(0, '/content/drive/My Drive/Bachelor Scriptie KI/Programming/Notebooks')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test = pd.read_csv("/content/drive/My Drive/Bachelor Scriptie KI/FinancialPhraseBank-v1.0/test.csv", sep=",", names=["Sentence", "Sentiment"], encoding="utf-8", skiprows=[0])

# %%
full_dataset = pd.read_csv("/content/drive/MyDrive/Bachelor Scriptie KI/FinancialPhraseBank-v1.0/Sentences_50Agree.txt", sep="@", names=["Sentence", "Sentiment"], encoding="latin-1")

# %%
print(test.info())
print(test.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485 entries, 2318 to 4756
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sentence   485 non-null    object
#  1   Sentiment  485 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 11.4+ KB
# None
#                                                Sentence  Sentiment
# 2318  tiimari latvian representative ineta zaharova ...          2
# 177            cargo volume increased approximately 5 %          2
# 4836  operating profits half 0.8 0.9 glisten investe...          0
# 495   delivers different user experience enables us ...          2
# 4394  strike finnair estimates incur net loss eur2m ...          0

# %% [markdown]
# # Lexicon-based approach

# %%
def convert_index_to_int(stringlist):
  intlist = []
  for index in stringlist:
    converted = int(index)
    intlist.append(converted)
  return intlist

# %%
def get_sentences(dataset, indices):
  errors = []
  for i in indices:
    errors.append(dataset.Sentence[i])
  return errors

# %%
def sentence_pipeline(dataset, stringlist):
  error_indices = convert_index_to_int(stringlist)
  error_sents = get_sentences(dataset, error_indices)
  for sent in error_sents:
    print(sent)
    print("-------------------------------")

# %% [markdown]
# ##Positive/neutral and neutral/positive

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_LB_financial_pos_neu.txt', 'r') as readfile:
    LB_pos_neu_error_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, LB_pos_neu_error_index_str)
# Out:
# CHS Expo Freight is a major Finnish fair , exhibition and culture logistics company that provides logistics services to various events by land , air and sea .
# -------------------------------
# COMPTEL CORPORATION Sami Ervio President and CEO Distribution : NASDAQ OMX Helsinki Major media Comptel Dynamic OSS solutions enable telecom service providers to deliver services flexibly and charge them effectively .
# -------------------------------
# With the second phase of the new Innova building , Tecnopolis presence in Jyvaskyla will increase to a total of approximately 62,000 floor square meters .
# -------------------------------
# The official opening of the office , located in Prague , will be celebrated on May 20 .
# -------------------------------
# The company had hoped the new plant would be on stream by the end of 2008 .
# -------------------------------
# TN means that the handset supports TeliaSonera 's Telia Navigator global positioning system service .
# ...

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_LB_financial_neu_pos.txt', 'r') as readfile:
    LB_neu_pos_error_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, LB_neu_pos_error_index_str)
# Out:
# It delivers a different user experience and enables us to widen the market we can address . ''
# -------------------------------
# Net sales in 2007 are expected to be 10 % up on 2006 .
# -------------------------------
# In January-September 2007 , the group 's net sales from continuing operations rose to EUR 213.1 mn from EUR 172.6 mn in the corresponding period in 2006 .
# -------------------------------
# Sales VAT inclusive expanded by 19 percent , to 351 million euros .
# -------------------------------
# Finnish construction group Lemminkainen Oyj HEL : LEM1S said today it has won a contract to provide technical services for the Nevsky Centre shopping mall to be opened in November in St Petersburg , Russia .
# -------------------------------
# Net sales surged by 18.5 % to EUR167 .8 m. Teleste said that EUR20 .4 m , or 12.2 % , of the sales came from the acquisitions made in 2009 .
# -------------------------------
# ...

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_LB_financial_tp_neu.txt', 'r') as readfile:
    LB_tp_neu_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, LB_tp_neu_index_str)
# Out:
# Rosa is one of the best-known Duckburg illustrators .
# -------------------------------
# Finnish Rautaruukki is selling its precision tube and automotive component processing unit Carl Froh in Germany to German Arques Industries .
# -------------------------------
# International operations accounted for over 80 % of net sales .
# -------------------------------
# The company will publish its financial statement for 2008 on February 25 , 2009 .
# -------------------------------
# The four-year contract between the bank and Ski Sport Finland will bring the bank 's advertisements to skiers helmets and caps .
# -------------------------------
# Okmetic revised its 2010 financial outlook based on its order book .
# -------------------------------
# Travel expenses would be reimbursed in accordance with the travel policy of the company .
# -------------------------------
# ...

# %% [markdown]
# #Traditional Machine Learning Approach

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_SVM_financial_pos_neu.txt', 'r') as readfile:
    SVM_pos_neu_error_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, SVM_pos_neu_error_index_str)
# Out:
# TN means that the handset supports TeliaSonera 's Telia Navigator global positioning system service .
# -------------------------------
# ` It is a testament to the quality of our LTE solution and our commitment to the Japanese market ' , he added .
# -------------------------------
# Glaston also has efficiency measures in all other units .
# -------------------------------
# Following this increase Huhtamaki 's registered share capital is EUR360 .62 m and the number of shares outstanding is 106,063,320 .
# -------------------------------
# Sales fell abroad but increased in Finland .
# -------------------------------
# The venture recently agreed to buy Motorola 's wireless networks business for $ 1.2 billion and to deploy LightSquared 's national 4G network .
# -------------------------------
# Viking Line and STX Finland said on Monday that there were plans to build a 240 million euro ferry that would be launched on the Turku-Stockholm route in spring 2013 .
# ...

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_SVM_financial_neu_pos.txt', 'r') as readfile:
    SVM_neu_pos_error_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, SVM_neu_pos_error_index_str)
# Out:
# Glaston , headquartered in Tampere , Finland , is a growing , international glass technology company .
# -------------------------------
# Net sales in 2007 are expected to be 10 % up on 2006 .
# -------------------------------
# This combined with foreign investments creates interesting opportunities for Solteq .
# -------------------------------
# With the launch of new 3G handsets , Nokia aims to become the winner in China 's 3G market as it did in the 2G market .
# -------------------------------
# The Ministry of Water in Tanzania has awarded Poyry a water and sanitation engineering assignment for the rehabilitation and extension of water supply and sanitation infrastructure in Bukoba and Musoma , situated at Lake Victoria in northern Tanzania .
# -------------------------------
# ...

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_SVM_financial_tp_neu.txt', 'r') as readfile:
    SVM_tp_neu_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, SVM_tp_neu_index_str)
# Out:
# Rosa is one of the best-known Duckburg illustrators .
# -------------------------------
# Finnish Rautaruukki is selling its precision tube and automotive component processing unit Carl Froh in Germany to German Arques Industries .
# -------------------------------
# International operations accounted for over 80 % of net sales .
# -------------------------------
# CHS Expo Freight is a major Finnish fair , exhibition and culture logistics company that provides logistics services to various events by land , air and sea .
# -------------------------------
# Among the biggest Christmas sellers were a  35 satin bow shift dress styled on outfits worn by Victoria Beckham and a  75 Paris Hilton Prom dress .
# -------------------------------
# COMPTEL CORPORATION Sami Ervio President and CEO Distribution : NASDAQ OMX Helsinki Major media Comptel Dynamic OSS solutions enable telecom service providers to deliver services flexibly and charge them effectively .
# ...

# %% [markdown]
# # BERT+CNN

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_DL_financial_pos_neu.txt', 'r') as readfile:
    DL_pos_neu_error_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, DL_pos_neu_error_index_str)
# Out:
# TN means that the handset supports TeliaSonera 's Telia Navigator global positioning system service .
# -------------------------------
# Apart from Nordea , also Ergo is competing for the position among the top three pension funds providers in Estonia .
# -------------------------------
# The changes in readership were not significant .
# -------------------------------
# ` It is a testament to the quality of our LTE solution and our commitment to the Japanese market ' , he added .
# -------------------------------
# The venture recently agreed to buy Motorola 's wireless networks business for $ 1.2 billion and to deploy LightSquared 's national 4G network .
# -------------------------------
# Viking Line and STX Finland said on Monday that there were plans to build a 240 million euro ferry that would be launched on the Turku-Stockholm route in spring 2013 .
# -------------------------------
# ...

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_DL_financial_neu_pos.txt', 'r') as readfile:
    DL_neu_pos_error_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, DL_neu_pos_error_index_str)
# Out:
# Glaston , headquartered in Tampere , Finland , is a growing , international glass technology company .
# -------------------------------
# Finnish silicon wafer technology company Okmetic Oyj ( OMX Helsinki : OKM1V ) reported on Thursday ( 7 August ) an operating profit of EUR5 .3 m for the period January-June 2008 , up from EUR3 .3 m in the corresponding period in 2007 .
# -------------------------------
# The company 's strength is its Apetit brand .
# -------------------------------
# After the reporting period , BioTie North American licensing partner Somaxon Pharmaceuticals announced positive results with nalmefene in a pilot Phase 2 clinical trial for smoking cessation .
# -------------------------------
# ( ADP News ) - Nov 28 , 2008 - Finnish power-supply solutions provider Efore Oyj ( OMX : EFO1V ) announced today the launch of OPUS DC , the latest power system in its OPUS product line .
# -------------------------------
# ...

# %%
with open('/content/drive/MyDrive/Bachelor Scriptie KI/Programming/Notebooks/Error Indexes/Financial/updated_DL_financial_tp_neu.txt', 'r') as readfile:
    DL_tp_neu_index_str = readfile.readlines()

# %%
sentence_pipeline(full_dataset, DL_tp_neu_index_str)
# Out:
# Rosa is one of the best-known Duckburg illustrators .
# -------------------------------
# Finnish Rautaruukki is selling its precision tube and automotive component processing unit Carl Froh in Germany to German Arques Industries .
# -------------------------------
# International operations accounted for over 80 % of net sales .
# -------------------------------
# CHS Expo Freight is a major Finnish fair , exhibition and culture logistics company that provides logistics services to various events by land , air and sea .
# -------------------------------
# Among the biggest Christmas sellers were a  35 satin bow shift dress styled on outfits worn by Victoria Beckham and a  75 Paris Hilton Prom dress .
# -------------------------------
# COMPTEL CORPORATION Sami Ervio President and CEO Distribution : NASDAQ OMX Helsinki Major media Comptel Dynamic OSS solutions enable telecom service providers to deliver services flexibly and charge them effectively .
# ...
